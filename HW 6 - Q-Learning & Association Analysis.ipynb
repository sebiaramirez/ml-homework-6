# %% [markdown]
# Name(s):

# %% [markdown]
# # HW 6: Q-Learning and Association Analysis

# %% [markdown]
# ## Part 1: Q-Learning
#
# For the first part of this assignment, you'll code an ML agent that uses Q-Learning to learn how to play Snake.
#
# <img src="snake_game.jpg" width="300"/>
#
#
# If you are not familiar with the game of Snake, read about how the game is played, and even play it yourself, [here](https://www.coolmathgames.com/blog/how-to-play-snake-mastering-a-classic).
#
# Once you understand how to play the game, continue with the assignment!

# %% [markdown]
# #### Imports

# %%
# you will need pygame installed
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.6.1)

# %%
import pygame
import random
import numpy as np

import pickle as pkl
import itertools

# the environment is provided in game_loop.py
from game_loop import *
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# imported game_loop

# %% [markdown]
# ### Game States
# For Q-Learning, the agent needs to keep a Q-Table of game states. To keep the number of possible game states manageable, we will define the game state as a combination of:
# * Horizontal orientation from the food - is the food currently to the left or the right of the snake's head? (-1: left, 0: same, 1: right)
# * Vertical orientation from the food - is the food currently above or below the snake's head? (-1: below, 0: same, 1: above)
# * What are in the squares adjacent to the snake's head - are there walls or snake tail in these squares? (1 indicates something is there, 0 indicates it is open)
#
# The environment (which is in the provided `game_loop.py` file) will provide this state in the form of two tuples:
# - The first tuple will contain (relative horizontal orientation to food, relative vertical orientation to food).
# - The second tuple will contain the squares surrounding the snake's head in the form of (up, down, left, right) where a 1 indicates wall or tail is in that square and 0 indicates that square is open.
#
# ### Snake Agent
# Below is a provided class for the SnakeAgent that will learn to play the game, using Q-Learning.
#
# Some methods have been provided for you - **do not change these**:
# * `__init__`: The constructor sets up some constants and sets the learning parameter values. Do not change the learning parameter values for part 1 of this assignment. It also calls init_qtable to initialize the Q-Table.
# * `init_qtable`: Initializes the Q-Table. The `qtable` is implemented as a dictionary of state -> list of four Q-Values, representing the four action choices of [left, right, up, down].
# * `save` and `load`: Saves the Q-Values (via pickle) so the agent can be re-loaded later via load.
#
# There are two additional methods in the SnakeAgent class **that you will implement**. These will be called by the `game_loop.py` file.
# * `act`: This method is responsible for selecting an action based on the current state.
# * `update`: This where the Q-values get updated based on the agent's actions and rewards during gameplay.

# %% [markdown]
# ### Implementation
#
# Q1. Implement the `act` method in the SnakeAgent class.
#
# The `act` method is responsible for selecting an action based on the current state, which is determined by the Snake's position and the relative position of the food. The agent can choose to explore randomly with a probability of epsilon or to exploit the learned Q-values to select the next action.
#
# In this method, you should:
# - Based on the current state, choose an action using an epsilon-greedy strategy
#   - Explore: Select a random action (0: left, 1: right, 2: up, 3: down)
#   - Exploit: Select the action with the highest Q-value for the current state
# - Record the current state and action, as you'll need these later for the update method (use `self.curr_state` and `self.curr_act`)
# - Return the chosen action as a string (use `self.ACTION_STRING_MAP` in the SnakeAgent class)

# %% [markdown]
# Q2. Implement the `update` method in the SnakeAgent class.
#
# The `update` method is a critical part of your SnakeAgent's learning process. It's where you update the Q-values based on the agent's actions and rewards during gameplay. Follow these steps to implement the `update` function:
#
# **Rewards**:
# Positive rewards are given for favorable actions, and negative rewards are given for unfavorable ones.
# - Check if the game is over using the `game_over` parameter. If it is over, give the agent a reward of -10 to indicate that the agent has lost the game.
# - If the game is not over, calculate the reward as follows:
#     - If the snake got closer to the food or if it ate the food, then set the reward to +1.
#     - If the snake got farther from the food or did not eat the food, then set the reward to -1.
# You can use `self.curr_dist_from_food` and the incoming parameter from the environment `dist_from_food` to help you determine this.
#
# **Update the Q-value for the state-action pair**:
# - With the current state and action, update the Q-value for this state-action pair using the Q-learning formula, where `max(Q(s_t_plus_1))` is the maximum Q-value for the next state:
# $$
# Q(s_t, a_t) = Q(s_t, a_t) + \alpha \cdot (R_t + \gamma \cdot \max_a Q(s_{t+1}, a) - Q(s_t, a_t))
# $$0

# %%
class SnakeAgent(object):
    '''
    Do not change this code, except for the 'act' and 'update' methods.
    '''
    def __init__(self, DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE):

        self.ACTION_STRING_MAP = {0: "left", 1: "right", 2: "up", 3: "down"}

        # Learning parameters - do not change these for Part 1
        self.epsilon = 0.1 # exploration rate
        self.alpha = 0.7 # learning rate
        self.gamma = 0.5 # discount factor

        # Initialize the Q-Table
        self.init_qtable()
        
        # State/Action history
        self.curr_state = None
        self.curr_act = None
        self.curr_dist_from_food = 1000

    def init_qtable(self):
        '''Initialize the qtable to all 0s'''
        self.qtable = {}
        REL_Y = [-1, 0, 1] # [below, same, above]
        REL_X = [-1, 0, 1] # [left, same, right]
        SURROUNDINGS = list(itertools.product(*[[0,1]] * 4)) # [0, 1] possibilities for surrounding block in each direction
        for y in REL_X:
            for x in REL_Y:
                for s in SURROUNDINGS:
                    self.qtable[QState((x, y), tuple(s))] = [0, 0, 0, 0] # q values for actions [left, right, up, down]

    def load(self, path="qtable.pkl"):
        return pkl.load(open(path, "rb"))

    def save(self, path="qtable.pkl"):
        pkl.dump(self.qtable, open(path, "wb"))
        
    
    '''
    Implement these methods:
    '''
    def act(self, state):
        #use epsilon-greedy
        if random.random() < self.epsilon:
            #pick a random action where (0: left, 1: right, 2: up, 3: down)
            action = random.randint(0, 3)
        else:
            #then choose action w/ highest q-value
            q_values = self.qtable[state]
            action = q_values.index(max(q_values))
        
        #record state and action
        self.curr_state = state
        self.curr_act = action

        #and return action as string
        return self.ACTION_STRING_MAP[action]
    
    def update(self, game_over, dist_from_food, new_state):  
        #get table of current q-values
        current_q_values = self.qtable[self.curr_state]
        
        #calculate reward based on specs
        if game_over:
            reward = -10
        else:
            #then check if it got rewarded
            if dist_from_food < self.curr_dist_from_food:
                #either ate the food or got closer 
                reward = 1
            else:
                #did not get closer
                reward = -1
        
        #get max q value for next state
        max_next_q = max(self.qtable[new_state])
        
        #update q-values: Q(s,a) = Q(s,a) + alpha * (reward + gamma * max(Q(s')) - Q(s,a))
        current_q = current_q_values[self.curr_act]
        new_q = current_q + self.alpha * (reward + self.gamma * max_next_q - current_q)
        
        #update table
        self.qtable[self.curr_state][self.curr_act] = new_q
        
        #update distance for next iteration
        self.curr_dist_from_food = dist_from_food

# %% [markdown]
# ### Game Loop
# The code in this cell will kick off the game, using your SnakeAgent, and will let your agent play for the specified number of eqisodes, keeping track of the scores as your agent learns how to play.

# %%
'''
Do not change the code in this cell!
(except for setting draw=False if you want to turn off the game visualization)
'''

pygame.init()

BLOCK_SIZE = 10 
DIS_WIDTH = 600
DIS_HEIGHT = 500
FRAMESPEED = 50000
NUM_EPISODES = 200

#create a SnakeAgent
agent = SnakeAgent(DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE)

game_count = 1
max_score = 0

# loop for specified number of episodes
for i in range(NUM_EPISODES):
    # use a decaying epsilon rate
    if game_count > 100:
        agent.epsilon = .01
    else:
        agent.epsilon = .1
        
    # Start the game
    # (To turn off the game visualizations, you can set draw=False)
    score = GameLoop(agent, DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE, FRAMESPEED, draw=True)
    
    max_score = max(max_score, score)
    print(f"Games: {game_count}; Score: {score}; Max Score: {max_score}") # Output results of each game to console to monitor as agent is training
    game_count += 1

agent.save()
print("Save Qvals")
pygame.quit()
# Out:
# Games: 1; Score: 1; Max Score: 1
# Games: 2; Score: 1; Max Score: 1
# Games: 3; Score: 1; Max Score: 1
# Games: 4; Score: 1; Max Score: 1
# Games: 5; Score: 1; Max Score: 1
# Games: 6; Score: 1; Max Score: 1
# Games: 7; Score: 1; Max Score: 1
# Games: 8; Score: 1; Max Score: 1
# Games: 9; Score: 1; Max Score: 1
# Games: 10; Score: 1; Max Score: 1
# Games: 11; Score: 1; Max Score: 1
# Games: 12; Score: 2; Max Score: 2
# Games: 13; Score: 1; Max Score: 2
# Games: 14; Score: 1; Max Score: 2
# Games: 15; Score: 1; Max Score: 2
# Games: 16; Score: 1; Max Score: 2
# Games: 17; Score: 1; Max Score: 2
# Games: 18; Score: 1; Max Score: 2
# Games: 19; Score: 1; Max Score: 2
# Games: 20; Score: 1; Max Score: 2
# Games: 21; Score: 1; Max Score: 2
# Games: 22; Score: 1; Max Score: 2
# Games: 23; Score: 1; Max Score: 2
# Games: 24; Score: 1; Max Score: 2
# Games: 25; Score: 3; Max Score: 3
# Games: 26; Score: 1; Max Score: 3
# Games: 27; Score: 1; Max Score: 3
# Games: 28; Score: 1; Max Score: 3
# Games: 29; Score: 1; Max Score: 3
# Games: 30; Score: 1; Max Score: 3
# Games: 31; Score: 1; Max Score: 3
# Games: 32; Score: 2; Max Score: 3
# Games: 33; Score: 2; Max Score: 3
# Games: 34; Score: 3; Max Score: 3
# Games: 35; Score: 1; Max Score: 3
# Games: 36; Score: 3; Max Score: 3
# Games: 37; Score: 1; Max Score: 3
# Games: 38; Score: 1; Max Score: 3
# Games: 39; Score: 1; Max Score: 3
# Games: 40; Score: 1; Max Score: 3
# Games: 41; Score: 1; Max Score: 3
# Games: 42; Score: 1; Max Score: 3
# Games: 43; Score: 1; Max Score: 3
# Games: 44; Score: 1; Max Score: 3
# Games: 45; Score: 1; Max Score: 3
# Games: 46; Score: 1; Max Score: 3
# Games: 47; Score: 1; Max Score: 3
# Games: 48; Score: 1; Max Score: 3
# Games: 49; Score: 1; Max Score: 3
# Games: 50; Score: 2; Max Score: 3
# Games: 51; Score: 1; Max Score: 3
# Games: 52; Score: 3; Max Score: 3
# Games: 53; Score: 1; Max Score: 3
# Games: 54; Score: 2; Max Score: 3
# Games: 55; Score: 1; Max Score: 3
# Games: 56; Score: 1; Max Score: 3
# Games: 57; Score: 3; Max Score: 3
# Games: 58; Score: 1; Max Score: 3
# Games: 59; Score: 1; Max Score: 3
# Games: 60; Score: 2; Max Score: 3
# Games: 61; Score: 1; Max Score: 3
# Games: 62; Score: 1; Max Score: 3
# Games: 63; Score: 1; Max Score: 3
# Games: 64; Score: 1; Max Score: 3
# Games: 65; Score: 3; Max Score: 3
# Games: 66; Score: 6; Max Score: 6
# Games: 67; Score: 1; Max Score: 6
# Games: 68; Score: 2; Max Score: 6
# Games: 69; Score: 1; Max Score: 6
# Games: 70; Score: 2; Max Score: 6
# Games: 71; Score: 2; Max Score: 6
# Games: 72; Score: 1; Max Score: 6
# Games: 73; Score: 3; Max Score: 6
# Games: 74; Score: 3; Max Score: 6
# Games: 75; Score: 2; Max Score: 6
# Games: 76; Score: 1; Max Score: 6
# Games: 77; Score: 1; Max Score: 6
# Games: 78; Score: 1; Max Score: 6
# Games: 79; Score: 2; Max Score: 6
# Games: 80; Score: 1; Max Score: 6
# Games: 81; Score: 1; Max Score: 6
# Games: 82; Score: 1; Max Score: 6
# Games: 83; Score: 1; Max Score: 6
# Games: 84; Score: 1; Max Score: 6
# Games: 85; Score: 1; Max Score: 6
# Games: 86; Score: 1; Max Score: 6
# Games: 87; Score: 2; Max Score: 6
# Games: 88; Score: 2; Max Score: 6
# Games: 89; Score: 1; Max Score: 6
# Games: 90; Score: 3; Max Score: 6
# Games: 91; Score: 1; Max Score: 6
# Games: 92; Score: 1; Max Score: 6
# Games: 93; Score: 4; Max Score: 6
# Games: 94; Score: 1; Max Score: 6
# Games: 95; Score: 3; Max Score: 6
# Games: 96; Score: 1; Max Score: 6
# Games: 97; Score: 2; Max Score: 6
# Games: 98; Score: 3; Max Score: 6
# Games: 99; Score: 1; Max Score: 6
# Games: 100; Score: 1; Max Score: 6
# Games: 101; Score: 6; Max Score: 6
# Games: 102; Score: 4; Max Score: 6
# Games: 103; Score: 13; Max Score: 13
# Games: 104; Score: 1; Max Score: 13
# Games: 105; Score: 3; Max Score: 13
# Games: 106; Score: 1; Max Score: 13
# Games: 107; Score: 1; Max Score: 13
# Games: 108; Score: 1; Max Score: 13
# Games: 109; Score: 6; Max Score: 13
# Games: 110; Score: 1; Max Score: 13
# Games: 111; Score: 3; Max Score: 13
# Games: 112; Score: 12; Max Score: 13
# Games: 113; Score: 8; Max Score: 13
# Games: 114; Score: 7; Max Score: 13
# Games: 115; Score: 3; Max Score: 13
# Games: 116; Score: 4; Max Score: 13
# Games: 117; Score: 4; Max Score: 13
# Games: 118; Score: 8; Max Score: 13
# Games: 119; Score: 5; Max Score: 13
# Games: 120; Score: 10; Max Score: 13
# Games: 121; Score: 1; Max Score: 13
# Games: 122; Score: 5; Max Score: 13
# Games: 123; Score: 3; Max Score: 13
# Games: 124; Score: 24; Max Score: 24
# Games: 125; Score: 13; Max Score: 24
# Games: 126; Score: 12; Max Score: 24
# Games: 127; Score: 24; Max Score: 24
# Games: 128; Score: 6; Max Score: 24
# Games: 129; Score: 8; Max Score: 24
# Games: 130; Score: 2; Max Score: 24
# Games: 131; Score: 1; Max Score: 24
# Games: 132; Score: 9; Max Score: 24
# Games: 133; Score: 7; Max Score: 24
# Games: 134; Score: 2; Max Score: 24
# Games: 135; Score: 2; Max Score: 24
# Games: 136; Score: 1; Max Score: 24
# Games: 137; Score: 7; Max Score: 24
# Games: 138; Score: 22; Max Score: 24
# Games: 139; Score: 5; Max Score: 24
# Games: 140; Score: 9; Max Score: 24
# Games: 141; Score: 19; Max Score: 24
# Games: 142; Score: 2; Max Score: 24
# Games: 143; Score: 11; Max Score: 24
# Games: 144; Score: 11; Max Score: 24
# Games: 145; Score: 11; Max Score: 24
# Games: 146; Score: 7; Max Score: 24
# Games: 147; Score: 3; Max Score: 24
# Games: 148; Score: 11; Max Score: 24
# Games: 149; Score: 22; Max Score: 24
# Games: 150; Score: 12; Max Score: 24
# Games: 151; Score: 12; Max Score: 24
# Games: 152; Score: 11; Max Score: 24
# Games: 153; Score: 2; Max Score: 24
# Games: 154; Score: 9; Max Score: 24
# Games: 155; Score: 6; Max Score: 24
# Games: 156; Score: 7; Max Score: 24
# Games: 157; Score: 4; Max Score: 24
# Games: 158; Score: 6; Max Score: 24
# Games: 159; Score: 15; Max Score: 24
# Games: 160; Score: 5; Max Score: 24
# Games: 161; Score: 14; Max Score: 24
# Games: 162; Score: 11; Max Score: 24
# Games: 163; Score: 1; Max Score: 24
# Games: 164; Score: 4; Max Score: 24
# Games: 165; Score: 6; Max Score: 24
# Games: 166; Score: 17; Max Score: 24
# Games: 167; Score: 27; Max Score: 27
# Games: 168; Score: 3; Max Score: 27
# Games: 169; Score: 25; Max Score: 27
# Games: 170; Score: 3; Max Score: 27
# Games: 171; Score: 5; Max Score: 27
# Games: 172; Score: 10; Max Score: 27
# Games: 173; Score: 3; Max Score: 27
# Games: 174; Score: 1; Max Score: 27
# Games: 175; Score: 1; Max Score: 27
# Games: 176; Score: 9; Max Score: 27
# Games: 177; Score: 4; Max Score: 27
# Games: 178; Score: 20; Max Score: 27
# Games: 179; Score: 10; Max Score: 27
# Games: 180; Score: 7; Max Score: 27
# Games: 181; Score: 1; Max Score: 27
# Games: 182; Score: 5; Max Score: 27
# Games: 183; Score: 10; Max Score: 27
# Games: 184; Score: 9; Max Score: 27
# Games: 185; Score: 8; Max Score: 27
# Games: 186; Score: 17; Max Score: 27
# Games: 187; Score: 6; Max Score: 27
# Games: 188; Score: 1; Max Score: 27
# Games: 189; Score: 25; Max Score: 27
# Games: 190; Score: 5; Max Score: 27
# Games: 191; Score: 6; Max Score: 27
# Games: 192; Score: 4; Max Score: 27
# Games: 193; Score: 13; Max Score: 27
# Games: 194; Score: 7; Max Score: 27
# Games: 195; Score: 8; Max Score: 27
# Games: 196; Score: 21; Max Score: 27
# Games: 197; Score: 16; Max Score: 27
# Games: 198; Score: 1; Max Score: 27
# Games: 199; Score: 41; Max Score: 41
# Games: 200; Score: 7; Max Score: 41
# Save Qvals

# %% [markdown]
# #### Saving and loading the trained agent
# The code above above saves your trained agent. You can use the cell below to load your trained agent and run it (so you don't have to re-train it).

# %%
agent.load()
pygame.init()
GameLoop(agent, DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE, FRAMESPEED, draw=True)
pygame.quit()

# %% [markdown]
# ### Extra Credit (+5)
# Improve the Agent's Performance. Can you get a max score above 80 within 300 episodes?
# Potential ideas: improve the state representation, change the reward function, change the hyperparameters, etc.
#
# **Copy BOTH the SnakeAgent class AND the Game Loop cell from above and paste them below in new cells. Make any extra credit adjustments to these copies, preserving your original SnakeAgent class and Game Loop so that Q1 and Q2 can be graded.**
#
# - Write in a markdown cell what you changed and what your observations were

# %%
class SnakeAgent(object):
    '''
    Do not change this code, except for the 'act' and 'update' methods.
    '''
    def __init__(self, DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE):

        self.ACTION_STRING_MAP = {0: "left", 1: "right", 2: "up", 3: "down"}

        # Learning parameters
        self.epsilon = 0.008 # exploration rate (initially)
        self.epsilon_min = 0.0005  #set a minimum rate
        self.epsilon_decay = 0.95  #decay factor per "episode"
        self.alpha = 0.1 # learning rate
        self.gamma = 0.9 # discount factor

        # Initialize the Q-Table
        self.init_qtable()
        
        # State/Action history
        self.curr_state = None
        self.curr_act = None
        self.curr_dist_from_food = 1000
        self.snake_direction = 1  #default direction


    def init_qtable(self):
        '''Initialize the qtable to all 0s'''
        self.qtable = {}
        REL_Y = [-1, 0, 1] # [below, same, above]
        REL_X = [-1, 0, 1] # [left, same, right]
        SURROUNDINGS = list(itertools.product(*[[0,1]] * 4)) # [0, 1] possibilities for surrounding block in each direction
        DIRECTIONS = [0, 1, 2, 3]  #left, right, up, down
        for y in REL_X:
            for x in REL_Y:
                for s in SURROUNDINGS:
                    self.qtable[QState((x, y), tuple(s))] = [0, 0, 0, 0] # q values for actions [left, right, up, down]

    def load(self, path="qtable.pkl"):
        return pkl.load(open(path, "rb"))

    def save(self, path="qtable.pkl"):
        pkl.dump(self.qtable, open(path, "wb"))

    def act(self, state):
        #use epsilon-greedy
        if random.random() < self.epsilon:
            #pick a random action where (0: left, 1: right, 2: up, 3: down)
            action = random.randint(0, 3)
        else:
            #then choose action w/ highest q-value
            q_values = self.qtable[state]
            action = q_values.index(max(q_values))
        
        #record state and action
        self.curr_state = state
        self.curr_act = action

        #and return action as string
        return self.ACTION_STRING_MAP[action]
    
    def update(self, game_over, dist_from_food, new_state):  
        #get table of current q-values
        current_q_values = self.qtable[self.curr_state]
        
        #calculate reward based on specs
        if game_over:
            #need to punish more
            reward = -100
        else:
            reward = -1 #for surviving 
            if dist_from_food == 0:
                reward = 50 #incentivize the goal
            elif dist_from_food < self.curr_dist_from_food:
                reward += 1.5 #incentivize getting closer
            # elif dist_from_food > self.curr_dist_from_food:
            #     reward -= 0.1 #also penalize for moving farther away
        
        #get max q value for next state
        max_next_q = max(self.qtable[new_state])
        
        #update q-values: Q(s,a) = Q(s,a) + alpha * (reward + gamma * max(Q(s')) - Q(s,a))
        current_q = current_q_values[self.curr_act]
        new_q = current_q + self.alpha * (reward + self.gamma * max_next_q - current_q)
        
        #update table
        self.qtable[self.curr_state][self.curr_act] = new_q
        
        #update distance for next iteration
        self.curr_dist_from_food = dist_from_food
    

    '''
Do not change the code in this cell!
(except for setting draw=False if you want to turn off the game visualization)
'''

pygame.init()

BLOCK_SIZE = 10 
DIS_WIDTH = 600
DIS_HEIGHT = 500
FRAMESPEED = 50000
NUM_EPISODES = 300

#create a SnakeAgent
agent = SnakeAgent(DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE)

game_count = 1
max_score = 0

# loop for specified number of episodes
for i in range(NUM_EPISODES):
    agent.epsilon = max(agent.epsilon_min, agent.epsilon * agent.epsilon_decay)
        
    # Start the game
    # (To turn off the game visualizations, you can set draw=False)
    score = GameLoop(agent, DIS_WIDTH, DIS_HEIGHT, BLOCK_SIZE, FRAMESPEED, draw=False)
    
    max_score = max(max_score, score)
    print(f"Games: {game_count}; Score: {score}; Max Score: {max_score}") # Output results of each game to console to monitor as agent is training
    game_count += 1

agent.save()
print("Save Qvals")
pygame.quit()
# Out:
# Games: 1; Score: 0; Max Score: 0
# Games: 2; Score: 1; Max Score: 1
# Games: 3; Score: 1; Max Score: 1
# Games: 4; Score: 1; Max Score: 1
# Games: 5; Score: 1; Max Score: 1
# Games: 6; Score: 1; Max Score: 1
# Games: 7; Score: 1; Max Score: 1
# Games: 8; Score: 1; Max Score: 1
# Games: 9; Score: 2; Max Score: 2
# Games: 10; Score: 1; Max Score: 2
# Games: 11; Score: 1; Max Score: 2
# Games: 12; Score: 2; Max Score: 2
# Games: 13; Score: 1; Max Score: 2
# Games: 14; Score: 1; Max Score: 2
# Games: 15; Score: 2; Max Score: 2
# Games: 16; Score: 4; Max Score: 4
# Games: 17; Score: 5; Max Score: 5
# Games: 18; Score: 16; Max Score: 16
# Games: 19; Score: 1; Max Score: 16
# Games: 20; Score: 10; Max Score: 16
# Games: 21; Score: 6; Max Score: 16
# Games: 22; Score: 14; Max Score: 16
# Games: 23; Score: 2; Max Score: 16
# Games: 24; Score: 4; Max Score: 16
# Games: 25; Score: 21; Max Score: 21
# Games: 26; Score: 3; Max Score: 21
# Games: 27; Score: 1; Max Score: 21
# Games: 28; Score: 4; Max Score: 21
# Games: 29; Score: 6; Max Score: 21
# Games: 30; Score: 4; Max Score: 21
# Games: 31; Score: 5; Max Score: 21
# Games: 32; Score: 6; Max Score: 21
# Games: 33; Score: 10; Max Score: 21
# Games: 34; Score: 12; Max Score: 21
# Games: 35; Score: 11; Max Score: 21
# Games: 36; Score: 19; Max Score: 21
# Games: 37; Score: 7; Max Score: 21
# Games: 38; Score: 10; Max Score: 21
# Games: 39; Score: 13; Max Score: 21
# Games: 40; Score: 4; Max Score: 21
# Games: 41; Score: 23; Max Score: 23
# Games: 42; Score: 4; Max Score: 23
# Games: 43; Score: 13; Max Score: 23
# Games: 44; Score: 18; Max Score: 23
# Games: 45; Score: 24; Max Score: 24
# Games: 46; Score: 13; Max Score: 24
# Games: 47; Score: 10; Max Score: 24
# Games: 48; Score: 27; Max Score: 27
# Games: 49; Score: 4; Max Score: 27
# Games: 50; Score: 18; Max Score: 27
# Games: 51; Score: 7; Max Score: 27
# Games: 52; Score: 36; Max Score: 36
# Games: 53; Score: 8; Max Score: 36
# Games: 54; Score: 24; Max Score: 36
# Games: 55; Score: 15; Max Score: 36
# Games: 56; Score: 22; Max Score: 36
# Games: 57; Score: 30; Max Score: 36
# Games: 58; Score: 6; Max Score: 36
# Games: 59; Score: 18; Max Score: 36
# Games: 60; Score: 28; Max Score: 36
# Games: 61; Score: 48; Max Score: 48
# Games: 62; Score: 30; Max Score: 48
# Games: 63; Score: 24; Max Score: 48
# Games: 64; Score: 43; Max Score: 48
# Games: 65; Score: 28; Max Score: 48
# Games: 66; Score: 35; Max Score: 48
# Games: 67; Score: 45; Max Score: 48
# Games: 68; Score: 29; Max Score: 48
# Games: 69; Score: 37; Max Score: 48
# Games: 70; Score: 5; Max Score: 48
# Games: 71; Score: 29; Max Score: 48
# Games: 72; Score: 39; Max Score: 48
# Games: 73; Score: 38; Max Score: 48
# Games: 74; Score: 34; Max Score: 48
# Games: 75; Score: 34; Max Score: 48
# Games: 76; Score: 41; Max Score: 48
# Games: 77; Score: 7; Max Score: 48
# Games: 78; Score: 3; Max Score: 48
# Games: 79; Score: 17; Max Score: 48
# Games: 80; Score: 19; Max Score: 48
# Games: 81; Score: 41; Max Score: 48
# Games: 82; Score: 25; Max Score: 48
# Games: 83; Score: 40; Max Score: 48
# Games: 84; Score: 27; Max Score: 48
# Games: 85; Score: 28; Max Score: 48
# Games: 86; Score: 32; Max Score: 48
# Games: 87; Score: 25; Max Score: 48
# Games: 88; Score: 57; Max Score: 57
# Games: 89; Score: 41; Max Score: 57
# Games: 90; Score: 29; Max Score: 57
# Games: 91; Score: 34; Max Score: 57
# Games: 92; Score: 29; Max Score: 57
# Games: 93; Score: 30; Max Score: 57
# Games: 94; Score: 7; Max Score: 57
# Games: 95; Score: 29; Max Score: 57
# Games: 96; Score: 18; Max Score: 57
# Games: 97; Score: 44; Max Score: 57
# Games: 98; Score: 57; Max Score: 57
# Games: 99; Score: 35; Max Score: 57
# Games: 100; Score: 42; Max Score: 57
# Games: 101; Score: 47; Max Score: 57
# Games: 102; Score: 48; Max Score: 57
# Games: 103; Score: 22; Max Score: 57
# Games: 104; Score: 38; Max Score: 57
# Games: 105; Score: 24; Max Score: 57
# Games: 106; Score: 41; Max Score: 57
# Games: 107; Score: 57; Max Score: 57
# Games: 108; Score: 20; Max Score: 57
# Games: 109; Score: 44; Max Score: 57
# Games: 110; Score: 5; Max Score: 57
# Games: 111; Score: 25; Max Score: 57
# Games: 112; Score: 25; Max Score: 57
# Games: 113; Score: 44; Max Score: 57
# Games: 114; Score: 73; Max Score: 73
# Games: 115; Score: 48; Max Score: 73
# Games: 116; Score: 42; Max Score: 73
# Games: 117; Score: 31; Max Score: 73
# Games: 118; Score: 5; Max Score: 73
# Games: 119; Score: 44; Max Score: 73
# Games: 120; Score: 46; Max Score: 73
# Games: 121; Score: 47; Max Score: 73
# Games: 122; Score: 59; Max Score: 73
# Games: 123; Score: 25; Max Score: 73
# Games: 124; Score: 23; Max Score: 73
# Games: 125; Score: 13; Max Score: 73
# Games: 126; Score: 49; Max Score: 73
# Games: 127; Score: 27; Max Score: 73
# Games: 128; Score: 33; Max Score: 73
# Games: 129; Score: 41; Max Score: 73
# Games: 130; Score: 31; Max Score: 73
# Games: 131; Score: 6; Max Score: 73
# Games: 132; Score: 16; Max Score: 73
# Games: 133; Score: 67; Max Score: 73
# Games: 134; Score: 41; Max Score: 73
# Games: 135; Score: 13; Max Score: 73
# Games: 136; Score: 46; Max Score: 73
# Games: 137; Score: 50; Max Score: 73
# Games: 138; Score: 48; Max Score: 73
# Games: 139; Score: 51; Max Score: 73
# Games: 140; Score: 26; Max Score: 73
# Games: 141; Score: 29; Max Score: 73
# Games: 142; Score: 7; Max Score: 73
# Games: 143; Score: 38; Max Score: 73
# Games: 144; Score: 32; Max Score: 73
# Games: 145; Score: 59; Max Score: 73
# Games: 146; Score: 24; Max Score: 73
# Games: 147; Score: 52; Max Score: 73
# Games: 148; Score: 16; Max Score: 73
# Games: 149; Score: 54; Max Score: 73
# Games: 150; Score: 44; Max Score: 73
# Games: 151; Score: 28; Max Score: 73
# Games: 152; Score: 61; Max Score: 73
# Games: 153; Score: 67; Max Score: 73
# Games: 154; Score: 49; Max Score: 73
# Games: 155; Score: 30; Max Score: 73
# Games: 156; Score: 33; Max Score: 73
# Games: 157; Score: 9; Max Score: 73
# Games: 158; Score: 60; Max Score: 73
# Games: 159; Score: 74; Max Score: 74
# Games: 160; Score: 76; Max Score: 76
# Games: 161; Score: 59; Max Score: 76
# Games: 162; Score: 16; Max Score: 76
# Games: 163; Score: 21; Max Score: 76
# Games: 164; Score: 86; Max Score: 86
# Games: 165; Score: 59; Max Score: 86
# Games: 166; Score: 84; Max Score: 86
# Games: 167; Score: 44; Max Score: 86
# Games: 168; Score: 24; Max Score: 86
# Games: 169; Score: 38; Max Score: 86
# Games: 170; Score: 38; Max Score: 86
# Games: 171; Score: 7; Max Score: 86
# Games: 172; Score: 41; Max Score: 86
# Games: 173; Score: 32; Max Score: 86
# Games: 174; Score: 34; Max Score: 86
# Games: 175; Score: 29; Max Score: 86
# Games: 176; Score: 64; Max Score: 86
# Games: 177; Score: 13; Max Score: 86
# Games: 178; Score: 52; Max Score: 86
# Games: 179; Score: 42; Max Score: 86
# Games: 180; Score: 42; Max Score: 86
# Games: 181; Score: 8; Max Score: 86
# Games: 182; Score: 45; Max Score: 86
# Games: 183; Score: 65; Max Score: 86
# Games: 184; Score: 39; Max Score: 86
# Games: 185; Score: 29; Max Score: 86
# Games: 186; Score: 54; Max Score: 86
# Games: 187; Score: 80; Max Score: 86
# Games: 188; Score: 20; Max Score: 86
# Games: 189; Score: 48; Max Score: 86
# Games: 190; Score: 21; Max Score: 86
# Games: 191; Score: 7; Max Score: 86
# Games: 192; Score: 38; Max Score: 86
# Games: 193; Score: 27; Max Score: 86
# Games: 194; Score: 56; Max Score: 86
# Games: 195; Score: 35; Max Score: 86
# Games: 196; Score: 33; Max Score: 86
# Games: 197; Score: 87; Max Score: 87
# Games: 198; Score: 51; Max Score: 87
# Games: 199; Score: 47; Max Score: 87
# Games: 200; Score: 43; Max Score: 87
# Games: 201; Score: 32; Max Score: 87
# Games: 202; Score: 13; Max Score: 87
# Games: 203; Score: 50; Max Score: 87
# Games: 204; Score: 70; Max Score: 87
# Games: 205; Score: 24; Max Score: 87
# Games: 206; Score: 55; Max Score: 87
# Games: 207; Score: 112; Max Score: 112
# Games: 208; Score: 24; Max Score: 112
# Games: 209; Score: 53; Max Score: 112
# Games: 210; Score: 59; Max Score: 112
# Games: 211; Score: 41; Max Score: 112
# Games: 212; Score: 117; Max Score: 117
# Games: 213; Score: 85; Max Score: 117
# Games: 214; Score: 30; Max Score: 117
# Games: 215; Score: 46; Max Score: 117
# Games: 216; Score: 71; Max Score: 117
# Games: 217; Score: 25; Max Score: 117
# Games: 218; Score: 72; Max Score: 117
# Games: 219; Score: 56; Max Score: 117
# Games: 220; Score: 52; Max Score: 117
# Games: 221; Score: 4; Max Score: 117
# Games: 222; Score: 53; Max Score: 117
# Games: 223; Score: 70; Max Score: 117
# Games: 224; Score: 25; Max Score: 117
# Games: 225; Score: 44; Max Score: 117
# Games: 226; Score: 66; Max Score: 117
# Games: 227; Score: 40; Max Score: 117
# Games: 228; Score: 30; Max Score: 117
# Games: 229; Score: 37; Max Score: 117
# Games: 230; Score: 58; Max Score: 117
# Games: 231; Score: 24; Max Score: 117
# Games: 232; Score: 3; Max Score: 117
# Games: 233; Score: 6; Max Score: 117
# Games: 234; Score: 29; Max Score: 117
# Games: 235; Score: 54; Max Score: 117
# Games: 236; Score: 77; Max Score: 117
# Games: 237; Score: 39; Max Score: 117
# Games: 238; Score: 7; Max Score: 117
# Games: 239; Score: 51; Max Score: 117
# Games: 240; Score: 21; Max Score: 117
# Games: 241; Score: 43; Max Score: 117
# Games: 242; Score: 49; Max Score: 117
# Games: 243; Score: 60; Max Score: 117
# Games: 244; Score: 42; Max Score: 117
# Games: 245; Score: 48; Max Score: 117
# Games: 246; Score: 73; Max Score: 117
# Games: 247; Score: 68; Max Score: 117
# Games: 248; Score: 38; Max Score: 117
# Games: 249; Score: 31; Max Score: 117
# Games: 250; Score: 60; Max Score: 117
# Games: 251; Score: 48; Max Score: 117
# Games: 252; Score: 78; Max Score: 117
# Games: 253; Score: 98; Max Score: 117
# Games: 254; Score: 69; Max Score: 117
# Games: 255; Score: 14; Max Score: 117
# Games: 256; Score: 51; Max Score: 117
# Games: 257; Score: 12; Max Score: 117
# Games: 258; Score: 14; Max Score: 117
# Games: 259; Score: 95; Max Score: 117
# Games: 260; Score: 19; Max Score: 117
# Games: 261; Score: 68; Max Score: 117
# Games: 262; Score: 58; Max Score: 117
# Games: 263; Score: 62; Max Score: 117
# Games: 264; Score: 26; Max Score: 117
# Games: 265; Score: 47; Max Score: 117
# Games: 266; Score: 35; Max Score: 117
# Games: 267; Score: 65; Max Score: 117
# Games: 268; Score: 15; Max Score: 117
# Games: 269; Score: 12; Max Score: 117
# Games: 270; Score: 50; Max Score: 117
# Games: 271; Score: 38; Max Score: 117
# Games: 272; Score: 38; Max Score: 117
# Games: 273; Score: 47; Max Score: 117
# Games: 274; Score: 21; Max Score: 117
# Games: 275; Score: 11; Max Score: 117
# Games: 276; Score: 63; Max Score: 117
# Games: 277; Score: 76; Max Score: 117
# Games: 278; Score: 23; Max Score: 117
# Games: 279; Score: 20; Max Score: 117
# Games: 280; Score: 67; Max Score: 117
# Games: 281; Score: 40; Max Score: 117
# Games: 282; Score: 20; Max Score: 117
# Games: 283; Score: 46; Max Score: 117
# Games: 284; Score: 83; Max Score: 117
# Games: 285; Score: 33; Max Score: 117
# Games: 286; Score: 3; Max Score: 117
# Games: 287; Score: 5; Max Score: 117
# Games: 288; Score: 32; Max Score: 117
# Games: 289; Score: 15; Max Score: 117
# Games: 290; Score: 31; Max Score: 117
# Games: 291; Score: 37; Max Score: 117
# Games: 292; Score: 56; Max Score: 117
# Games: 293; Score: 59; Max Score: 117
# Games: 294; Score: 65; Max Score: 117
# Games: 295; Score: 24; Max Score: 117
# Games: 296; Score: 69; Max Score: 117
# Games: 297; Score: 1; Max Score: 117
# Games: 298; Score: 14; Max Score: 117
# Games: 299; Score: 44; Max Score: 117
# Games: 300; Score: 35; Max Score: 117
# Save Qvals

# %% [markdown]
# ## Part 2: Association Analysis
#
# Association analysis uses machine learning to extract frequent itemsets and strong association rules from large datasets. In this assignment you'll be implementing one of the most commonly used algorithms for association rule mining - the Apriori algorithm.
#
# The dataset (`large_retail.txt`) that we are going to use has been adapted from the [Retail Market Basket Dataset](http://fimi.ua.ac.be/data/retail.pdf). This dataset contains transaction records supplied by a Belgian retail supermarket store. Each line in the file represents a separate transaction with the item ids separated by space. The dataset has 3000 transactions and 99 different item ids.
#
# You are also provided with a smaller dataset (`small_retail.txt`) with 9 transactions and 5 different item ids. You can test and debug your implementation on this smaller dataset.

# %% [markdown]
# ### Apriori Algorithm from scratch
#
# The Apriori algorithm is a classical algorithm in data mining. It is used for mining frequent itemsets and relevant association rules. In this part, you'll be implementing this algorithm for generating the itemsets that occur enough times to meet the `min_sup` threshold.
#
# - Use the `frozenset` data structure in Python, which is similar to `set` in functionality, to represent the itemsets, because `frozenset` is an immutable (hashable) data structure. You can maintain a dictionary that maps from the itemset (a `frozenset`) to its support count.

# %%
# Reading the dataset from file
def load_dataset(file_name):
    with open(file_name, 'r') as f:
        content = f.readlines()
        data = [[int(x) for x in line.rstrip().split()] for line in content]
    return data

# %%
# Read in the small_retail dataset
small_dataset = load_dataset('small_retail.txt')
small_dataset
# Out:
# [[1, 2, 5],
#  [2, 4],
#  [2, 3],
#  [1, 2, 4],
#  [1, 3],
#  [2, 3],
#  [1, 3],
#  [1, 2, 3, 5],
#  [1, 2, 3]]

# %% [markdown]
# Q3. Implement the function `create_1_itemsets` that takes as input the entire dataset and returns a list of all the candidate 1-itemsets. For example, for `small_retail.txt` it should return:
# ~~~
# [frozenset({1}),
#  frozenset({2}),
#  frozenset({3}),
#  frozenset({4}),
#  frozenset({5})]
#  ~~~
# Don't hardcode the item ids, your code should support item ids that are non-sequential. Return the list in sorted (numeric) order.

# %%
def create_1_itemsets(dataset):
    c1 = []
    # your code goes here
    return c1

# %% [markdown]
# Q4. Implement function `filter_candidates` that takes as input the candidate itemsets, the dataset, and the minumum support count `min_sup`, and filters out candidates that don't meet the support threshold.
#
# Return a list of all the itemsets that meet `min_sup` (as a list of frozensets) and the support count information for all of them (as a `dict`).

# %%
def filter_candidates(candidates, dataset, min_sup):
    retlist = []
    support_data = {}
    # your code goes here
    return retlist, support_data

# %% [markdown]
# Q5. Implement the function `generate_next_itemsets` that takes in frequent itemsets of size `k` and generates candidate itemsets of size `k + 1`.
#
# Use either the F(k-1) x F(k-1) or the F(k-1) x F(1) candidate generation method, then **filter the candidate list based on the apriori principle before returning it.**

# %%
def generate_next_itemsets(freq_sets, freq_1_sets=None):
    retlist = []
    # your code goes here
    return retlist

# %% [markdown]
# Q6. Implement the function `apriori_freq_itemsets` that takes the entire dataset as input and returns all the frequent itemsets that meet `min_sup`. Return a list of all the itemsets that meet `min_sup` (as a list of frozensets) and the support count information for all of them (as a `dict`).

# %%
def apriori_freq_itemsets(dataset, minsup):
    retlist = []
    support_data = {}
    # your code goes here
    return retlist, support_data

# %% [markdown]
# Q7. Use the provided `print_itemsets` function to display the frequent itemsets and their supports for the `large_retail.txt` dataset **with a min_support count of 300**.
#
# For testing/debugging purposes, the output for the `small_retail.txt` dataset with `min_sup` set to 2 is:
# ~~~~
# Sup	Freq Itemset
# 6	[1]
# 7	[2]
# 6	[3]
# 2	[4]
# 2	[5]
# 4	[1, 2]
# 4	[1, 3]
# 2	[1, 5]
# 4	[2, 3]
# 2	[2, 4]
# 2	[2, 5]
# 2	[1, 2, 3]
# 2	[1, 2, 5]
# ~~~~

# %%
# DO NOT CHANGE THE CODE IN THIS CELL

'''
If total_tid is not set, support count will be displayed.
If total_tid is set to the length of the dataset, support as a percentage/ratio will be displayed.
'''
def print_itemsets(support_data, total_tid=1):
    print ('\nSup\tFreq Itemset')
    #group itemsets by length
    length_dict = {}
    
    for itemset in support_data:
        #sort the itemset
        lst = (sorted(list(itemset)))
        #add it to dictionary by length
        if len(lst) not in length_dict:
            length_dict[len(lst)] = []
        length_dict[len(lst)].append(lst)

    for length in length_dict:
        lst = sorted(length_dict[length])
        for item in lst:
            if total_tid == 1: #support count
                print(str(support_data[frozenset(item)]) + '\t' + str(item))
            else: #support ratio
                print(str(round(support_data[frozenset(item)] / total_tid, 2)) + '\t' + str(item))

# %%
# your code goes here

# %% [markdown]
# ## Part 3: Apriori Algorithm using MLXtend
#
# #### Installation
# `MLxtend` is a library that provides functionality for association rule mining. The documentation for this library is available [here](http://rasbt.github.io/mlxtend/).

# %%
# install the MLxtend library
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.16.3 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (2.4.0)
# Requirement already satisfied: pandas>=2.3.3 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\sebia\AppData\Roaming\Python\Python313\site-packages (from matplotlib>=3.10.8->mlxtend) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\sebia\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Downloading mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 9.8 MB/s  0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.24.0

# %%
import matplotlib.pyplot as plt
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %matplotlib inline

# %% [markdown]
# ### Dataset
# For the third part of this assignment, the data we'll use comes from a bakery called "The Bread Basket", located in the historic center of Edinburgh. The dataset contains more than 9000 transactions from the bakery. The file contains the following columns:
#
# - Date. Categorical variable that tells us the date of the transactions (YYYY-MM-DD format). The column includes dates from 2016-10-30 to 2017-04-09.
#
# - Time. Categorical variable that tells us the time of the transactions (HH:MM:SS format).
#
# - Transaction. Quantitative variable that allows us to differentiate the transactions. The rows that share the same value in this field belong to the same transaction.
#
# - Item. Categorical variable with the products purchased.
#
# In this part, you'll be running the Apriori algorithm from the MLxtend library to generate the itemsets that occur more than the `min_sup` threshold. Based on these frequent itemsets, you'll find association rules that have confidence above the `min_conf` threshold.

# %%
# Reading the dataset from file
def load_dataset(file_name):
    with open(file_name, 'r') as f:
        content = f.readlines()[1:]
    transactions = []
    prev_tid = -1
    for t in content:
        t = t.strip().split(',')[-2:]
        tid = t[0]
        item = t[1]
        if prev_tid != tid:
            prev_tid = tid
            transactions.append([item])
        else:
            transactions[-1].append(item)
    return transactions

# %%
dataset = load_dataset('BreadBasket_DMS.csv')

# ** NOTE: dataset is a 2D list (not a dataframe!) **

print("Num transactions:", len(dataset))
#Print the first 10 transactions
dataset[:10]
# Out:
# Num transactions: 9531
# [['Bread'],
#  ['Scandinavian', 'Scandinavian'],
#  ['Hot chocolate', 'Jam', 'Cookies'],
#  ['Muffin'],
#  ['Coffee', 'Pastry', 'Bread'],
#  ['Medialuna', 'Pastry', 'Muffin'],
#  ['Medialuna', 'Pastry', 'Coffee', 'Tea'],
#  ['Pastry', 'Bread'],
#  ['Bread', 'Muffin'],
#  ['Scandinavian', 'Medialuna']]

# %% [markdown]
# Q8. Data Cleaning: Many transactions in the dataset include the item "NONE." First, find and remove all the "NONE" items from the dataset. There are some transactions that only contain "NONE," so removing "NONE" will leave some transactions as empty lists. Remove all the empty lists as well.
#
# Once you have removed the NONEs, find the top 15 best-selling items in the bakery. Create a bar chart to display the total number of transactions for each of the top 15 selling items. Sort the bar chart by frequency (the top most sold item first, down to the 15th most sold item).

# %%
# your code goes here

# %% [markdown]
# Q9.
#
# a.) Using `mlxtend.preprocessing.TransactionEncoder`, transform `dataset` into an array format suitable for the `mlxtend` library. You will need to call `fit` then `transform`.
#
# `TransactionEncoder` learns unique items from the dataset and transforms each transaction into a one-hot encoded boolean numpy array. For example, the resulting encoded dataset will be represented by something like this, where each row is a transaction. If the first transaction contained ['Crepe', 'Jam'], this would correspond to the first row in the encoded table.
#
# <img src="table.png">
#
# Print the `shape` of the resulting encoded numpy array.
#
# b.) `TransactionEncoder` also has a function `inverse_transform` that allows you to tranform one-hot encoded transactions back to the item labels. Try it out on the first 5 transactions and display the items in the first 5 transactions.

# %%
# your code goes here

# %% [markdown]
# Q10. Convert the encoded numpy array from the previous question (part a) into a pandas dataframe. Use the `TransactionEncoder`'s `.columns_` attribute as the column headers. Print the head of the resulting dataframe.

# %%
# your code goes here

# %% [markdown]
# Q11. Use the `mlxtend.frequent_patterns.apriori` to generate the frequent itemsets with minimum support of 1% (0.01). Display these itemsets along with their support values.

# %%
# your code goes here

# %% [markdown]
# Q12. Use `mlxtend.frequent_patterns.fpmax` to find and display all of the maximal frequent itemsets along with their support values.

# %%
# your code goes here

# %% [markdown]
# Q13. Use `mlxtend.frequent_patterns.association_rules` to calculate rules with a confidence level of 0.30 for the frequent itemsets you generated in Q11.

# %%
# your code goes here

# %% [markdown]
# Q14. An important step in generating a set of association rules is to determine the optimal thresholds for support and confidence. If we set these values too low we will get a lot of rules and most of them will not be useful.
#
# Generate the frequent itemsets with minimum support of 0.5% and plot the number of rules generated with respect to the confidence threshold by varying min_conf between 0 and 1 with increments of 0.1. Notice what happens when you increase the confidence level.

# %%
# your code goes here

# %% [markdown]
# Q15. What value would you choose for the minimum confidence threshold based on the previous plot? Explain why as a comment.
#
# Display the rules generated for the your chosen value. Take a look at the generated rules. Are they interesting? As a comment, explain why or why not.

# %%
# your code goes here
